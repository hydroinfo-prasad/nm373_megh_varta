# %%
#from geopy.geocoders import Nominatim
import numpy as np
#import rasterio
from PIL import Image
import matplotlib.pyplot as plt

# %%
#change city if you want different coordinates
# geolocator = Nominatim(user_agent="megh_varta")

# city = "kanpur"
# location = geolocator.geocode(city)
# city, lat, lon = location.raw['display_name'], location.raw['lat'], location.raw['lon']
# print(city, '\n', "latitude: ", lat, '\n', "longitude: ", lon)
# Out:
# Kanpur, NH34, Kidwai Nagar, Kanpur, Kanpur Nagar, Uttar Pradesh, 208012, India
#  latitude:  26.4609135
#  longitude:  80.3217588

# %%
# xs = np.array([130.5, 146.0])
# ys = np.array([-25.5, -42.0])
# xs = np.float(lon)  #longitude
# ys =  np.float(lat)  #lattitude

#  lattitude:  26.4609135 
#  longitude:  80.3217588

# with rasterio.open("CMK_Cropped_16.tif") as src:
#     rows, cols = rasterio.transform.rowcol(src.transform, xs, ys)

# print(rows, cols)

img = Image.open('CMK_Cropped_16.tif')
arr = np.asarray(img)
output = arr[rows, cols]
#print('Pixel value at ',lat,lon,'(Latitude,Longitude) is',output)

# %%
pixel_value = (246,345)

plt.imshow(np.array(Image.open("CMK_Cropped_16.tif")))

# %%
pixels = img.load()
pixels[rows, cols] = [255, 0, 0]
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-13-a0405a7d9af5> in <module>
#       1 pixels = img.load()
# ----> 2 pixels[rows, cols] = [255, 0, 0]
#
# SystemError: new style getargs format but argument is not a tuple

# %%
pixels
